# %% [raw]
# Amisha Meka
# Week 5 Dask Programming Assignment
# HDS 5230 - High Performance Computing

# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np

dtypes = {
    'country': 'object',
    'state': 'object',
    'city': 'object',
    'aggregate': 'object',
    'date': 'object',  # We'll parse this to datetime later
    'deaths': 'float64',
    'population': 'float64',
    'cases': 'float64'

}

# Load the CSV file into a Dask DataFrame
df = dd.read_csv('timeseries.csv', dtype=dtypes)

# Convert date column to datetime
df['date'] = dd.to_datetime(df['date'])

# Now extract year-month

df['year_month'] = df['date'].dt.strftime('%Y-%m')

# %%
# Filter for U.S. states
df = df[(df['country'] == 'United States') & (df['state'].notnull())]

# Filter for the required time period
df = df[(df['date'] >= '2020-01-01') & (df['date'] <= '2021-02-28')]

# Group by state and compute total deaths and average population over the period
state_stats = df.groupby('state').agg({'deaths': 'sum', 'population': 'mean'}).compute()
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)

# %% [raw]
# The process of filtering U.S. state data alongside date ranges demonstrates perfect compatibility with parallel and distributed computation because different parts of the dataset can process independent operations. The distributed nature of Dask benefits filtering and grouping operations on large datasets with millions of records through parallel processing of its split datasets. When the dataset can fit entirely in memory parallelization will add more execution complexity than necessary.

# %%
state_stats['per_capita_mortality'] = state_stats['deaths'] / state_stats['population']

# Rank states based on per-capita mortality
ranked_states = state_stats.sort_values(by='per_capita_mortality', ascending=False)
print(ranked_states)
# Out:
#                                  deaths    population  per_capita_mortality
# state
# New York                      3852431.0  6.023470e+05              6.395701
# Michigan                       880814.0  2.748462e+05              3.204753
# Louisiana                      423430.0  1.548027e+05              2.735288
# Illinois                       765763.0  3.746646e+05              2.043863
# New Jersey                    1710535.0  8.421302e+05              2.031200
# Georgia                        309920.0  1.529650e+05              2.026085
# Pennsylvania                   758770.0  4.142725e+05              1.831572
# Virginia                       186685.0  1.373630e+05              1.359063
# Mississippi                    104608.0  7.710448e+04              1.356705
# Indiana                        217660.0  1.608219e+05              1.353423
# Ohio                           308006.0  2.908617e+05              1.058943
# ...

# %% [raw]
# The calculation to sum total deaths and cases by state and month represents an **embarrassingly parallel problem** that separates processing between independent state-month pairs. The way distributed computation makes perfect sense in this situation because sum operations along with `sum()` work efficiently across partitioned data before efficient merging takes place. Most significantly processing large datasets needs both computational efficiency and abundant memory capacity when parallelism is absent.

# %%
# Extract year-month for grouping
df['year_month'] = df['date'].dt.strftime('%Y-%m')

monthly_stats = df.groupby(['state', 'year_month']).agg({'deaths': 'sum', 'cases': 'sum'}).compute()

monthly_stats['CFR'] = monthly_stats['deaths'] / monthly_stats['cases']

monthly_stats = monthly_stats.fillna(0)

monthly_stats = monthly_stats.sort_index()
monthly_stats
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
#                      deaths      cases       CFR
# state   year_month
# Alabama 2020-03        64.0    12023.0  0.005323
#         2020-04      7073.0   249850.0  0.028309
#         2020-05     28789.0   740216.0  0.038893
#         2020-06     47377.0  1599004.0  0.029629
#         2020-07      9836.0   412970.0  0.023818
# ...                     ...        ...       ...
# Wyoming 2020-03         0.0     1540.0  0.000000
#         2020-04        81.0    20451.0  0.003961
#         2020-05       354.0    45419.0  0.007794
#         2020-06      1021.0    67428.0  0.015142
#         2020-07       100.0    15772.0  0.006340
#
# [290 rows x 3 columns]

# %% [raw]
# Although simple the CFR calculation (deaths/cases per month per state) gains advantages from parallel execution because it depends on previously executed aggregations which were parallelized. The data processing speed is primarily affected by the movement of data instead of the simple division computation because of its simplicity. Large datasets benefit from parallel execution because it allows efficient calculations across partitioned data sets although smaller datasets might not experience significant speedup from such parallel processing.
#
#
# The use of `.diff()` method to calculate monthly CFR changes allows some degree of parallel processing. The individual CFR values from different states throughout the months operate independently yet the '.diff()' operation must conserve the correct order of months within each state. Part of the synchronization operation becomes necessary at the group level which constrains the possibility of full parallel execution. Parallelization continues to decrease processing duration even if dealing with numerous states.

# %%
monthly_stats['CFR_change'] = monthly_stats.groupby('state')['CFR'].diff()

state_cfr_variation = monthly_stats.groupby('state')['CFR_change'].sum().sort_values(ascending=False)
state_cfr_variation
# Out:
# state
# New Jersey                      0.078497
# Connecticut                     0.076860
# Massachusetts                   0.074380
# Pennsylvania                    0.063375
# New Hampshire                   0.061680
# Michigan                        0.061298
# Rhode Island                    0.057596
# New York                        0.051587
# Illinois                        0.048028
# Maryland                        0.043883
# Colorado                        0.041244
# Minnesota                       0.039581
# Washington                      0.039217
# Washington, D.C.                0.038932
# Ohio                            0.037465
# New Mexico                      0.032985
# West Virginia                   0.030047
# Indiana                         0.029179
# Missouri                        0.027825
# Delaware                        0.026790
# Maine                           0.026276
# California                      0.025430
# Wisconsin                       0.024958
# ...

# %% [raw]
# The calculation and ordering of state CFR variations needs to collect results from every partition in order to work as a global operation. Parallel computation applies to summation but the ranking operation mostly requires sorting that demonstrates low parallelization potential. The final ranking operation receives less benefit from parallel execution because it needs to operate on a single node after receiving complete part results.
